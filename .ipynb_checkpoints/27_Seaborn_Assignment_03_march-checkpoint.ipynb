# %% [markdown]
# ### Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Scatter Plot:
# 1. Use: To visualize the relationship between two numerical variables.
# 2. Seaborn Function: seaborn.scatterplot()
#
# Line Plot:
# 1. Use: To display the trend or change in values over time or other dimensions.
# 2. Seaborn Function: seaborn.lineplot()
#
# Bar Plot:
# 1. Use: To compare and display categorical data.
# 2. Seaborn Function: seaborn.barplot()
#
# Histogram:
# 1. Use: To visualize the distribution of a numerical variable.
# 2. Seaborn Function: seaborn.histplot()
#
# Heatmap:
# 1. Use: To show the relationship between two variables in a tabular format using colors.
# 2. Seaborn Function: seaborn.heatmap()

# %% [markdown]
# ### Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
#
# #### Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
import seaborn as sns
df = sns.load_dataset("fmri")
sns.lineplot(data =df, x="timepoint",y="signal",hue='event',style='region')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ### Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.
#
# #### Note: pclass, age, and fare are columns in the titanic dataset.

# %%
df = sns.load_dataset('titanic')

sns.boxplot(data=df,x='pclass',y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=df,x='pclass',y='fare')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# ### Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
df = sns.load_dataset('diamonds')
sns.histplot(data=df,x='price',hue='cut',multiple='stack')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ### Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
df = sns.load_dataset('iris')
sns.pairplot(data=df,hue='species')

# %% [markdown]
# ### Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights = sns.load_dataset('flights')

flights_pivot = flights.pivot_table(index='month', columns='year', values='passengers')

sns.heatmap(flights_pivot, cmap='YlOrRd')


plt.show()
