# %% [markdown]
# ### Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# Using the Exception class as the base for custom exceptions provides necessary attributes and behaviors, compatibility with existing exception handling mechanisms, and allows for unified exception handling. It also enables organizing exceptions within the Python exception hierarchy.

# %% [markdown]
# ### Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
#             SSLError
# ...

# %% [markdown]
# ### Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError class in Python is the base class for arithmetic-related exceptions.

# %% [markdown]
# ZeroDivisionError: This exception is raised when attempting to divide a number by zero.

# %%
def divide_numbers(a, b):
    try:
        result = a / b
        print(f"The result of division is: {result}")
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")

divide_numbers(10, 0)
# Out:
# Error: Division by zero is not allowed.

# %% [markdown]
# OverflowError: This exception is raised when the result of an arithmetic operation exceeds the maximum representable value.

# %%
def calculate_factorial(n):
    try:
        factorial = 1
        for i in range(1, n+1):
            factorial *= i
        print(f"The factorial of {n} is: {factorial}")
    except ValueError:
        print("Error: Result exceeds the maximum representable value.")

calculate_factorial(10000)
# Out:
# Error: Result exceeds the maximum representable value.

# %% [markdown]
# ### Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# The LookupError class in Python is the base class for exceptions that occur when a lookup or indexing operation fails. It serves as the parent class for exceptions like KeyError and IndexError.

# %%
dic_marks={"kunal":90,"Goranshi":95,"Mona":85}

try:
    mark=dic_marks["Divek"]
    print(f"marks are{mark}")
except KeyError:
    print("key not found in the dictionary")
# Out:
# key not found in the dictionary

# %% [markdown]
# ### Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError is an exception in Python that is raised when an imported module or a module attribute cannot be found or accessed.
#
# ModuleNotFoundError is a subclass of ImportError that specifically indicates that a module cannot be found or imported.

# %% [markdown]
# ### Q6. List down some best practices for exception handling in python.

# %% [markdown]
# we shoudl use finally and else block so that is some error occur our application will not stop working
#
# we should use multuple except to handle varaity of the errors
